-- %%
select * from 03_gold.default.dim_customer;

-- %%
select * from 03_gold.default.dim_product;

-- %%
select * from 03_gold.default.dim_store;

-- %%
select * from 03_gold.default.dim_date

-- %%
select * from 03_gold.default.fact_sales

-- %%
select * from 03_gold.default.fact_returns

-- %%
select * from 03_gold.default.fact_inventory
