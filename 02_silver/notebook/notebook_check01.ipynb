-- %%
SELECT * FROM 02_silver.default.sales;

-- %%
SELECT * FROM 02_silver.default.customers;

-- %%
SELECT * FROM 02_silver.default.products;

-- %%
SELECT * FROM 02_silver.default.inventory;

-- %%
SELECT * FROM 02_silver.default.returns;

-- %%
SELECT * FROM 02_silver.default.stores;
